# %%
# import os
# from openai import OpenAI

# %%
# client = OpenAI(
#     base_url="https://router.huggingface.co/v1",
#     api_key=os.environ["HUGGING_FACE_TOKEN"],
# )

# %%
# completion = client.chat.completions.create(
#     model="moonshotai/Kimi-K3:together",
#     messages=[
#         {
#             "role": "user",
#             "content": [
#                 {"type": "text", "text": "You are a very intelligent model which answers user's questions"},
#                 {"type": "text", "text": "Do you know about Fable 5 model?"}
#             ]
#         }
#     ],
# )

# %%
# completion

# %%
# from langchain_ollama import ChatOllama

# %%
# model = ChatOllama(model='phi4-mini:latest')

# %%
# result = model.invoke("hey there i am having a doubt")

# %%
# result

# %%
# from langchain_cerebras import ChatCerebras
# from dotenv import load_dotenv
# import os

# load_dotenv()
# llm = ChatCerebras(model="gemma-4-31b", api_key=os.environ.get("CEREBRAS_API_KEY_1"))
# print(llm.invoke("say hi").content)

# %%
# from langchain_google_genai import GoogleGenerativeAIEmbeddings

# %%
# model = GoogleGenerativeAIEmbeddings(model='gemini-embedding-2', api_key=os.environ.get("GEMINI_API_KEY_1"))

# %%
# model.embed_query("Hey there")

# %%
import os
from langchain_groq import ChatGroq
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
model = ChatGroq(model='qwen/qwen3.6-27b', api_key=os.environ.get("GROQ_API_KEY_6"))

# %%
model.invoke("how are you")
# Out:
# AIMessage(content='\n<think>\nHere\'s a thinking process:\n\n1.  **Analyze User Input:**\n   - User says: "how are you"\n   - This is a standard greeting/check-in question.\n   - It\'s informal and expects a friendly, conversational response.\n\n2.  **Identify Key Requirements:**\n   - Acknowledge the greeting\n   - Respond appropriately (friendly, polite)\n   - Keep it concise\n   - Optionally ask how they\'re doing or offer help\n\n3.  **Formulate Response (Internal Refinement):**\n   - "I\'m doing well, thank you for asking! How are you doing? Is there anything I can help you with today?"\n   - This is standard, polite, and opens the door for further interaction.\n\n4.  **Check Against Guidelines:**\n   - No specific constraints violated\n   - Matches expected AI behavior\n   - Tone is appropriate\n\n5.  **Final Output Generation:** (matches the refined version)\n   - "I\'m doing well, thank you for asking! How are you doing? Is there anything I can help you with today?"✅\n</think>\n\nI\'m doing well, thank you for asking! How are you doing? Is there anything I can help you with today? 😊', additional_kwargs={}, response_metadata={'token_usage': {'completion_tokens': 263, 'prompt_tokens': 13, 'total_tokens': 276, 'completion_time': 0.515852835, 'completion_tokens_details': None, 'prompt_time': 0.000731625, 'prompt_tokens_details': None, 'queue_time': 0.045253431, 'total_time': 0.51658446}, 'model_name': 'qwen/qwen3.6-27b', 'system_fingerprint': 'fp_60e0d2f248', 'service_tier': 'on_demand', 'finish_reason': 'stop', 'logprobs': None, 'model_provider': 'groq'}, id='lc_run--01a00455-d63e-7723-a4ed-b0b577783ca8-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 263, 'total_tokens': 276})

# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings
import os

# %%
model = GoogleGenerativeAIEmbeddings(model="gemini-embedding-2", api_key=os.environ.get("GEMINI_API_KEY_4"))

# %%
model.embed_query("How are you")
# Out:
# ---------------------------------------------------------------------------
# ClientError                               Traceback (most recent call last)
# File c:\Voice Agent\venv\Lib\site-packages\langchain_google_genai\embeddings.py:497, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     496 try:
# --> 497     result = self.client.models.embed_content(
#     498         model=self.model,
#     499         contents=text,
#     500         config=config,
#     501     )
#     502 except ClientError as e:
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\models.py:6454, in Models.embed_content(self, model, contents, config)
#    6453     contents = t.t_contents(contents)  # type: ignore[assignment]
# -> 6454   return self._embed_content(model=model, contents=contents, config=config)
#    6456 if t.t_is_vertex_embed_content_model(model):
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\models.py:5257, in Models._embed_content(self, model, contents, content, embedding_api_type, config)
#    5255 request_dict = _common.encode_unserializable_types(request_dict)
# -> 5257 response = self._api_client.request(
#    5258     'post', path, request_dict, http_options
#    5259 )
#    5261 response_dict = {} if not response.body else json.loads(response.body)
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\_api_client.py:1708, in BaseApiClient.request(self, http_method, path, request_dict, http_options)
#    1705 http_request = self._build_request(
#    1706     http_method, path, request_dict, http_options
#    1707 )
# -> 1708 response = self._request(http_request, http_options, stream=False)
#    1709 response_body = (
#    1710     response.response_stream[0] if response.response_stream else ''
#    1711 )
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\_api_client.py:1495, in BaseApiClient._request(self, http_request, http_options, stream)
#    1493     return retry(self._request_once, http_request, stream)  # type: ignore[no-any-return]
# -> 1495 return self._retry(self._request_once, http_request, stream)
#
# File c:\Voice Agent\venv\Lib\site-packages\tenacity\__init__.py:470, in Retrying.__call__(self, fn, *args, **kwargs)
#     469 while True:
# --> 470     do = self.iter(retry_state=retry_state)
#     471     if isinstance(do, DoAttempt):
#
# File c:\Voice Agent\venv\Lib\site-packages\tenacity\__init__.py:371, in BaseRetrying.iter(self, retry_state)
#     370 for action in self.iter_state.actions:
# --> 371     result = action(retry_state)
#     372 return result
#
# File c:\Voice Agent\venv\Lib\site-packages\tenacity\__init__.py:413, in BaseRetrying._post_stop_check_actions.<locals>.exc_check(rs)
#     412 if self.reraise:
# --> 413     raise retry_exc.reraise()
#     414 raise retry_exc from fut.exception()
#
# File c:\Voice Agent\venv\Lib\site-packages\tenacity\__init__.py:184, in RetryError.reraise(self)
#     183 if self.last_attempt.failed:
# --> 184     raise self.last_attempt.result()
#     185 raise self
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:443, in Future.result(self, timeout)
#     442 elif self._state == FINISHED:
# --> 443     return self.__get_result()
#     445 self._condition.wait(timeout)
#
# File ~\AppData\Local\Python\pythoncore-3.14-64\Lib\concurrent\futures\_base.py:395, in Future.__get_result(self)
#     394 try:
# --> 395     raise self._exception
#     396 finally:
#     397     # Break a reference cycle with the exception in self._exception
#
# File c:\Voice Agent\venv\Lib\site-packages\tenacity\__init__.py:473, in Retrying.__call__(self, fn, *args, **kwargs)
#     472 try:
# --> 473     result = fn(*args, **kwargs)
#     474 except BaseException:  # noqa: B902
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\_api_client.py:1472, in BaseApiClient._request_once(self, http_request, stream)
#    1471   response = self._httpx_client.send(httpx_request, stream=stream)  # type: ignore[union-attr]
# -> 1472 errors.APIError.raise_for_response(response)
#    1473 return HttpResponse(
#    1474     response.headers, response if stream else [response.text]
#    1475 )
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\errors.py:155, in APIError.raise_for_response(cls, response)
#     153   response_json = response.body_segments[0].get('error', {})
# --> 155 cls.raise_error(response.status_code, response_json, response)
#
# File c:\Voice Agent\venv\Lib\site-packages\google\genai\errors.py:184, in APIError.raise_error(cls, status_code, response_json, response)
#     183 if 400 <= status_code < 500:
# --> 184   raise ClientError(status_code, response_json, response)
#     185 elif 500 <= status_code < 600:
#
# ClientError: 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}
#
# The above exception was the direct cause of the following exception:
#
# GoogleGenerativeAIError                   Traceback (most recent call last)
# Cell In[7], line 1
# ----> 1 model.embed_query("How are you")
#
# File c:\Voice Agent\venv\Lib\site-packages\langchain_google_genai\embeddings.py:504, in GoogleGenerativeAIEmbeddings.embed_query(self, text, task_type, title, output_dimensionality)
#     502 except ClientError as e:
#     503     msg = f"Error embedding content ({e.status}): {e}"
# --> 504     raise GoogleGenerativeAIError(msg) from e
#     505 except Exception as e:
#     506     msg = f"Error embedding content: {e}"
#
# GoogleGenerativeAIError: Error embedding content (PERMISSION_DENIED): 403 PERMISSION_DENIED. {'error': {'code': 403, 'message': 'Your project has been denied access. Please contact support.', 'status': 'PERMISSION_DENIED'}}
